# %%
import sys
sys.path
# Out:
# ['/Users/mr/miniconda3/lib/python312.zip',
#  '/Users/mr/miniconda3/lib/python3.12',
#  '/Users/mr/miniconda3/lib/python3.12/lib-dynload',
#  '',
#  '/Users/mr/miniconda3/lib/python3.12/site-packages']
